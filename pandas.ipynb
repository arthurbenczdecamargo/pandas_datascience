# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv"
data = pd.read_csv(url, sep=";")
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
data.shape
# Out:
# (32960, 9)

# %%
data.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
data.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
data.describe()
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#          Condominio          IPTU
# count  2.886700e+04  2.272300e+04
# mean   2.388062e+03  2.364410e+03
# std    3.918496e+04  1.795641e+05
# min    1.000000e+00  1.000000e+00
# 25%    5.900000e+02  1.100000e+02
# 50%    9.900000e+02  2.500000e+02
# 75%    1.800000e+03  6.970000e+02
# ...

# %%
data["Tipo"]
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
data[["Quartos", "Valor"]].head()
# Out:
#    Quartos   Valor
# 0        1  1700.0
# 1        2  7000.0
# 2        0  5200.0
# 3        1   800.0
# 4        1   800.0

# %%
data["Valor"].mean()
# Out:
# 12952.659715265761

# %%
data.groupby("Tipo")[["Valor"]].mean(numeric_only=True).sort_values("Valor")
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
df_price_type = (
    data.groupby("Tipo")[["Valor"]].mean(numeric_only=True).sort_values("Valor")
)

# %%
df_price_type.plot(kind="barh", figsize=(14, 10), color="blue")
# Out:
# <Axes: ylabel='Tipo'>

# %%
data.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
commercial = [
    "Conjunto Comercial/Sala",
    "Prédio Inteiro",
    "Loja/Salão",
    "Galpão/Depósito/Armazém",
    "Casa Comercial",
    "Terreno Padrão",
    "Loja Shopping/ Ct Comercial",
    "Box/Garagem",
    "Chácara",
    "Loteamento/Condomínio",
    "Sítio",
    "Pousada/Chalé",
    "Hotel",
    "Indústria",
]

# %%
data.query("@commercial in Tipo").head()
# Out:
#                        Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2   Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9   Conjunto Comercial/Sala           Centro        0      3       0   695
# 16           Prédio Inteiro         Botafogo        0      0       0   536
# 26  Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29               Loja/Salão     Campo Grande        0      1       0    35
#
#       Valor  Condominio    IPTU
# 2    5200.0      4020.0  1111.0
# 9   35000.0     19193.0  3030.0
# 16  28000.0         NaN  3563.0
# 26   1100.0       600.0     NaN
# 29   1300.0       950.0     NaN

# %%
data.query("@commercial not in Tipo").head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %%
df = data.query("@commercial not in Tipo")

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_price_type = (
    df.groupby("Tipo")[["Valor"]].mean(numeric_only=True).sort_values("Valor")
)

# %%
df_price_type.plot(kind="barh", figsize=(14, 10), color="blue")
# Out:
# <Axes: ylabel='Tipo'>

# %%
df.Tipo.value_counts(normalize=True).to_frame().sort_values("Tipo")
# Out:
#                     proportion
# Tipo
# Apartamento           0.845139
# Casa                  0.041842
# Casa de Condomínio    0.043096
# Casa de Vila          0.010774
# Flat                  0.020596
# Loft                  0.002207
# Quitinete             0.036173
# Studio                0.000173

# %%
df_percentage_type = df.Tipo.value_counts(normalize=True).to_frame().sort_values("Tipo")

# %%
df_percentage_type.plot(
    kind="bar", figsize=(14, 10), color="red", xlabel="Tipos", ylabel="Percentage"
)
# Out:
# <Axes: xlabel='Tipos', ylabel='Percentage'>

# %%
df = df.query("Tipo == 'Apartamento'")
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %%
df.isnull().sum()
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            7
# Condominio     745
# IPTU          5472
# dtype: int64

# %%
df = df.fillna(0)
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   0.0
# 5          0.0   0.0
# 6        301.0  17.0
# 10         0.0   0.0

# %%
df.isnull().sum()
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %%
df.query("Valor == 0 | Condominio == 0").head()
# Out:
#             Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 5    Apartamento     Vista Alegre        3      1       0    70  1200.0
# 10   Apartamento           Centro        1      0       0    36  1200.0
# 76   Apartamento  Barra da Tijuca        2      1       1    70     0.0
# 113  Apartamento       Praça Seca        2      0       0    80  1000.0
# 166  Apartamento    Rocha Miranda        2      1       0    50  1100.0
#
#      Condominio  IPTU
# 5           0.0   0.0
# 10          0.0   0.0
# 76        970.0  68.0
# 113         0.0   0.0
# 166         0.0   0.0

# %%
df.query("Valor == 0 | Condominio == 0").index
# Out:
# Index([    5,    10,    76,   113,   166,   194,   258,   265,   275,   292,
#        ...
#        32420, 32438, 32480, 32538, 32584, 32609, 32643, 32666, 32708, 32809],
#       dtype='int64', length=752)

# %%
remove_null = df.query("Valor == 0 | Condominio == 0").index
df.drop(remove_null, axis=0, inplace=True)

# %%
df.query("Valor == 0 | Condominio == 0")
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
df.Tipo.unique()
# Out:
# array(['Apartamento'], dtype=object)

# %%
df.drop("Tipo", axis=1, inplace=True)
df.head()
# Out:
#                  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3                Centro        1      0       0    15   800.0       390.0
# 4          Higienópolis        1      0       0    48   800.0       230.0
# 6              Cachambi        2      0       0    50  1300.0       301.0
# 11               Grajaú        2      1       0    70  1500.0       642.0
# 12  Lins de Vasconcelos        3      1       1    90  1500.0       455.0
#
#     IPTU
# 3   20.0
# 4    0.0
# 6   17.0
# 11  74.0
# 12  14.0

# %%
query1 = df["Quartos"] == 1
df[query1].head()
# Out:
#           Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  IPTU
# 3         Centro        1      0       0    15   800.0       390.0  20.0
# 4   Higienópolis        1      0       0    48   800.0       230.0   0.0
# 13    Copacabana        1      0       1    40  2000.0       561.0  50.0
# 28        Tijuca        1      0       0    48   750.0       772.0  25.0
# 54        Centro        1      0       0    27   750.0       371.0  19.0

# %%
query2 = df["Valor"] < 1200
df[query2].head(10)
# Out:
#                       Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3                     Centro        1      0       0    15   800.0
# 4               Higienópolis        1      0       0    48   800.0
# 19   Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 23                    Olaria        3      1       0    68  1000.0
# 28                    Tijuca        1      0       0    48   750.0
# 54                    Centro        1      0       0    27   750.0
# 77                  Cachambi        2      0       0    60  1000.0
# 91            Vila Valqueire        2      1       0    45   800.0
# 94                    Centro        1      1       0    37  1100.0
# 106                Itanhangá        2      1       0    60  1000.0
#
#      Condominio   IPTU
# 3         390.0   20.0
# 4         230.0    0.0
# 19        300.0   28.0
# 23        670.0    0.0
# 28        772.0   25.0
# 54        371.0   19.0
# 77        380.0  280.0
# 91        280.0   14.0
# ...

# %%
final_query = (query1) & (query2)
df[final_query].head(10)
# Out:
#                       Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3                     Centro        1      0       0    15   800.0
# 4               Higienópolis        1      0       0    48   800.0
# 28                    Tijuca        1      0       0    48   750.0
# 54                    Centro        1      0       0    27   750.0
# 94                    Centro        1      1       0    37  1100.0
# 148              Vila Isabel        1      0       0    37  1000.0
# 293                 Botafogo        1      0       0    35  1000.0
# 355             Engenho Novo        1      1       0    63   700.0
# 385                 Maracanã        1      1       1   120  1000.0
# 576  Freguesia (Jacarepaguá)        1      1       0    49  1050.0
#
#      Condominio   IPTU
# 3         390.0   20.0
# 4         230.0    0.0
# 28        772.0   25.0
# 54        371.0   19.0
# 94        540.0  900.0
# 148       285.0   24.0
# 293       293.0   86.0
# 355       625.0   36.0
# ...

# %%
select = (df["Quartos"] >= 2) & (df["Valor"] < 3000) & (df["Area"] > 70)
df[select].head(10)
# Out:
#                       Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 12       Lins de Vasconcelos        3      1       1    90  1500.0
# 21                    Tijuca        2      1       0   110  1900.0
# 24                    Tijuca        2      1       0    78  2000.0
# 32                  Botafogo        2      1       0    76  2500.0
# 36  Recreio dos Bandeirantes        3      1       1   105  2300.0
# 48  Recreio dos Bandeirantes        3      2       2   100  2600.0
# 49           Barra da Tijuca        3      1       1    72  2350.0
# 51  Recreio dos Bandeirantes        3      1       2    92  2300.0
# 57  Recreio dos Bandeirantes        2      1       2    83  1600.0
# 64                     Méier        3      1       0    90  1550.0
#
#     Condominio   IPTU
# 12       455.0   14.0
# 21       700.0  138.0
# 24       700.0    0.0
# 32       740.0    0.0
# 36       648.0    0.0
# 48       380.0    0.0
# 49       600.0   70.0
# 51       840.0  200.0
# ...

# %%
df.to_csv("data_apartments.csv", index=False, sep=";")

# %%
data_apartments = pd.read_csv("data_apartments.csv", sep=";")
data_apartments.head(15)
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0                    Centro        1      0       0    15    800.0
# 1              Higienópolis        1      0       0    48    800.0
# 2                  Cachambi        2      0       0    50   1300.0
# 3                    Grajaú        2      1       0    70   1500.0
# 4       Lins de Vasconcelos        3      1       1    90   1500.0
# 5                Copacabana        1      0       1    40   2000.0
# 6                Copacabana        4      3       1   243  13000.0
# 7   Freguesia (Jacarepaguá)        3      0       0    54    950.0
# 8           Barra da Tijuca        2      1       1    67   1700.0
# 9                    Tijuca        2      1       0   110   1900.0
# 10                   Olaria        3      1       0    68   1000.0
# 11                   Tijuca        2      1       0    78   2000.0
# 12                  Ipanema        3      1       1   125   7000.0
# ...

# %%
data_apartments["Price/month"] = (
    data_apartments["Valor"] + data_apartments["Condominio"]
)
data_apartments.head(15)
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0                    Centro        1      0       0    15    800.0
# 1              Higienópolis        1      0       0    48    800.0
# 2                  Cachambi        2      0       0    50   1300.0
# 3                    Grajaú        2      1       0    70   1500.0
# 4       Lins de Vasconcelos        3      1       1    90   1500.0
# 5                Copacabana        1      0       1    40   2000.0
# 6                Copacabana        4      3       1   243  13000.0
# 7   Freguesia (Jacarepaguá)        3      0       0    54    950.0
# 8           Barra da Tijuca        2      1       1    67   1700.0
# 9                    Tijuca        2      1       0   110   1900.0
# 10                   Olaria        3      1       0    68   1000.0
# 11                   Tijuca        2      1       0    78   2000.0
# 12                  Ipanema        3      1       1   125   7000.0
# ...

# %%
data_apartments["Price/year"] = (
    data_apartments["Price/month"] * 12 + data_apartments["IPTU"]
)
data_apartments.head(15)
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0                    Centro        1      0       0    15    800.0
# 1              Higienópolis        1      0       0    48    800.0
# 2                  Cachambi        2      0       0    50   1300.0
# 3                    Grajaú        2      1       0    70   1500.0
# 4       Lins de Vasconcelos        3      1       1    90   1500.0
# 5                Copacabana        1      0       1    40   2000.0
# 6                Copacabana        4      3       1   243  13000.0
# 7   Freguesia (Jacarepaguá)        3      0       0    54    950.0
# 8           Barra da Tijuca        2      1       1    67   1700.0
# 9                    Tijuca        2      1       0   110   1900.0
# 10                   Olaria        3      1       0    68   1000.0
# 11                   Tijuca        2      1       0    78   2000.0
# 12                  Ipanema        3      1       1   125   7000.0
# ...

# %%
data_apartments["Has_suite"] = data_apartments["Suites"].apply(
    lambda x: "Yes" if x > 0 else "No"
)
data_apartments.head(15)
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0                    Centro        1      0       0    15    800.0
# 1              Higienópolis        1      0       0    48    800.0
# 2                  Cachambi        2      0       0    50   1300.0
# 3                    Grajaú        2      1       0    70   1500.0
# 4       Lins de Vasconcelos        3      1       1    90   1500.0
# 5                Copacabana        1      0       1    40   2000.0
# 6                Copacabana        4      3       1   243  13000.0
# 7   Freguesia (Jacarepaguá)        3      0       0    54    950.0
# 8           Barra da Tijuca        2      1       1    67   1700.0
# 9                    Tijuca        2      1       0   110   1900.0
# 10                   Olaria        3      1       0    68   1000.0
# 11                   Tijuca        2      1       0    78   2000.0
# 12                  Ipanema        3      1       1   125   7000.0
# ...

# %%
data_apartments["Description"] = (
    data_apartments["Quartos"].astype(str)
    + " room(s) apartment in "
    + data_apartments["Bairro"]
    + " with "
    + data_apartments["Vagas"].astype(str)
    + " garage space(s)."
)
data_apartments.head(10)
# Out:
#                     Bairro  Quartos  Vagas  Suites  Area    Valor  Condominio  \
# 0                   Centro        1      0       0    15    800.0       390.0
# 1             Higienópolis        1      0       0    48    800.0       230.0
# 2                 Cachambi        2      0       0    50   1300.0       301.0
# 3                   Grajaú        2      1       0    70   1500.0       642.0
# 4      Lins de Vasconcelos        3      1       1    90   1500.0       455.0
# 5               Copacabana        1      0       1    40   2000.0       561.0
# 6               Copacabana        4      3       1   243  13000.0      2000.0
# 7  Freguesia (Jacarepaguá)        3      0       0    54    950.0       300.0
# 8          Barra da Tijuca        2      1       1    67   1700.0       589.0
# 9                   Tijuca        2      1       0   110   1900.0       700.0
#
#     IPTU  Price/month  Price/year Has_suite  \
# 0   20.0       1190.0     14300.0        No
# ...

# %%
data_apartments.to_csv('data_apartments_updated.csv', index=False, sep=';')
